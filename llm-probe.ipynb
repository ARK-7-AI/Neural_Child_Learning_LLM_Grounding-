# %%
# !pip install transformers accelerate sentencepiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (7.1.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.1 MB/s eta 0:00:0000:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 9.2 MB/s eta 0:00:000:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import os
os.listdir('/kaggle/input/one-word-learning')
# Out:
# ['one_word_learning.csv']

# %%
import json
import pandas as pd
from sklearn.model_selection import train_test_split
import random


df = pd.read_csv("/kaggle/input/one-word-learning/one_word_learning.csv")
df.head()
print(f"Loaded: {len(df)} rows | Columns: {df.columns.tolist()}")

# adult/child columns
adult_col = next(c for c in df.columns if "adult" in c.lower())
child_col = next(c for c in df.columns if "child" in c.lower())

df_filtered = df[[adult_col, child_col]].copy()
df_filtered.columns = ["adult", "child"]

adults = df_filtered["adult"].astype(str).tolist()
children = df_filtered["child"].astype(str).tolist()

adult_train, adult_test, child_train, child_test = train_test_split(
    adults, children, test_size=0.2, random_state=42, shuffle=True
)

train_pairs = [{"adult": a, "child": c} for a, c in zip(adult_train, child_train)]
test_pairs = [{"adult": a, "child": c} for a, c in zip(adult_test, child_test)]

print(f"Train: {len(train_pairs)}, Test: {len(test_pairs)}")
# Out:
# Loaded: 16000 rows | Columns: ['adult', 'child']
# Train: 12800, Test: 3200

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Qwen/Qwen2.5-1.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto"
)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# 2025-12-10 19:23:16.273537: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765394596.465206      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765394596.519784      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
# K-short Learning
def build_prompt(train_examples, adult_utterance, k=10):
    sample = random.sample(train_examples, k)
    
    ex_lines = "\n".join([
        f"{i+1}. {e['adult']} -> {e['child']}"
        for i, e in enumerate(sample)
    ])

    prompt = (
        "You are an early child.\n"
        "Use ONLY the provided examples to answer the question.\n"
        "Each example shows something an adult says and what the child repeats.\n\n"
        f"Examples:\n{ex_lines}\n\n"
        f"Q: {adult_utterance}\nA:"
        " I REPEAT DO NOT USE YOUR OWN PRIOR KNOWLEDGE, ONLY THE EXAMPLES PROVIDED!!"
    )
    return prompt

# %%
def run_llm_batch(prompts, max_new_tokens=10):
    inputs = tokenizer(
        prompts,
        return_tensors="pt",
        padding=True,
        truncation=True
    ).to(model.device)

    outputs = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False,
        temperature=0.0,
    )

    decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    
    answers = [txt.split("A:")[-1].strip() for txt in decoded]
    return answers

# %%
results = []
batch_size = 16  
num_test = len(test_pairs)

for start in range(0, num_test, batch_size):
    end = min(start + batch_size, num_test)
    batch_pairs = test_pairs[start:end]

    # build batch prompt 
    batch_prompts = [
        build_prompt(train_pairs, t["adult"], k=10)
        for t in batch_pairs
    ]

    # run the model on the batch
    batch_answers = run_llm_batch(batch_prompts, max_new_tokens=10)

    # collect results
    for t, ans in zip(batch_pairs, batch_answers):
        results.append({"adult": t["adult"], "expected": t["child"], "llm": ans})
        print(f"{t['adult']} → {ans}")


with open("qwen_results.json", "w") as f:
    json.dump(results, f, indent=2)

# %%
def evaluate_results(input_path, output_path):
    data = json.load(open(input_path))
    results = []

    for item in data:
        adult = item["adult"]
        expected = item["expected"].lower().strip()
        llm = item["llm"].lower().strip()

        hallucinated = False
        label = "unknown"

        if expected == 'unkown':
            total_unkown += 1

        uncertainty_phrases = [
            "unknown", "not sure", "don't know", "no information",
            "couldn't find", "can't determine", "no example",
            "based on the provided", "not enough information",
            "i don't have", "unable to"
        ]
        expresses_uncertainty = any(p in llm for p in uncertainty_phrases)

        if expected != "unknown" and expected in llm and not expresses_uncertainty:
            label = "correct"
        elif expected != "unknown" and llm not in ["", expected] and not expresses_uncertainty:
            label = "incorrect"
        elif expected == "unknown" and expresses_uncertainty:
            label = "uncertain"
        elif expected == "unknown" and not expresses_uncertainty and llm not in ["", "unknown"]:
            label = "hallucination"
            hallucinated = True
        elif expected != "unknown" and expresses_uncertainty:
            label = "false_uncertainty"
        elif llm == "" or llm == "unknown":
            label = "no_output"

        results.append({
            "adult": adult,
            "expected": expected,
            "llm": llm,
            "label": label,
            "hallucinated": hallucinated
        })

    summary = {
        "correct": sum(r["label"] == "correct" for r in results),
        "incorrect": sum(r["label"] == "incorrect" for r in results),
        "uncertain": sum(r["label"] == "uncertain" for r in results),
        "hallucination": sum(r["label"] == "hallucination" for r in results),
        "false_uncertainty": sum(r["label"] == "false_uncertainty" for r in results),
        "no_output": sum(r["label"] == "no_output" for r in results)
    }

    print("=== Evaluation Summary ===")
    for k, v in summary.items():
        print(f"{k:20s} {v}")


    # Separate lists
    known_items = [r for r in results if r['expected'] != "unknown"]
    unknown_items = [r for r in results if r['expected'] == "unknown"]
    
    # Known Accuracy
    known_correct = sum(r["label"] == "correct" for r in known_items)
    known_total = len(known_items)
    known_accuracy = known_correct / known_total * 100 if known_total > 0 else 0
    
    # Unknown Accuracy (avoid hallucinations)
    unknown_correct = sum(r["label"] in ["uncertain", "no_output"] for r in unknown_items)
    unknown_total = len(unknown_items)
    unknown_accuracy = unknown_correct / unknown_total * 100 if unknown_total > 0 else 0
    
    print("\n=== Accuracy ===")
    print(f"Known Accuracy:   {known_accuracy:.1f}% ({known_correct}/{known_total})")
    print(f"Unknown Accuracy: {unknown_accuracy:.1f}% ({unknown_correct}/{unknown_total})")

    json.dump(results, open(output_path, "w"), indent=2)
    
    return results

# %%
evaluate_results("qwen_results.json", "qwen_scored.json")
# Out:
# === Evaluation Summary ===
# correct              1572
# incorrect            569
# uncertain            53
# hallucination        879
# false_uncertainty    115
# no_output            12
#
# === Accuracy ===
# Known Accuracy:   69.3% (1572/2267)
# Unknown Accuracy: 5.8% (54/933)
# [{'adult': '- Can I help you?',
#   'expected': 'help',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nunknown to be helpful, i would',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': "So it's back in the box.",
#   'expected': 'box',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "box" as they repeat',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "WELL, DON'T WORRY.",
#   'expected': "don't",
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ni don't worry. �",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'the flower .',
#   'expected': 'flower',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nflower\nbaby\nnight\npig',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "that's a pretty .",
#   'expected': 'pretty',
#   'llm': 'pretty',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Their eyes, their little games.',
#   'expected': 'eyes',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: their eyes, their little games. child',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'You know, his eyes.',
#   'expected': 'eyes',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "you know, his eyes." child',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "not an apple it's a jelly bean mark ?",
#   'expected': 'apple',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: not an apple it's a jelly bean",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'what does a cow say ?',
#   'expected': 'cow',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would repeat "moo" as the',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "I couldn't find a babysitter.",
#   'expected': 'babysitter',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "i can\'t find a babysitter',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "- It's a TV and it's working!",
#   'expected': 'tv',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early_child::it's_a_tv_and_it's",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "where's my baby ?",
#   'expected': 'baby',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: where's my baby? child: i",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "that's what's in that book ?",
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: that's what's in that book?",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Why i buy the car?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ncar\nnight\nsee the nose',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'A night on the grog will straighten them out.',
#   'expected': 'night',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! hands-up for the night on the g',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'How would that help losing you?',
#   'expected': 'help',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: how would that help losing you? child',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'New car, or not, you despise me for it.',
#   'expected': 'car',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! new car, or not, you despite',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': '-You dog, open your pretty mouth and talk.',
#   'expected': 'dog',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndog\nmouth\ntalk\nopen',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Finish it.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "what do you think of this movie',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'bright light ?',
#   'expected': 'light',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "bright light?" child: "night',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "But it's personal at home.",
#   'expected': 'home',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndo not use your own prior knowledge',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "oh he can't write with a spoon ?",
#   'expected': 'spoon',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nnope, he can't write",
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'I need your help.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ni need help. \n\nexplanation:',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "don't hurt me i might cry .",
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndon't hurt me i might cry",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': '- Hi.',
#   'expected': 'hi',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nhi. -> hi. \n\nthe',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Oh, Cookie shake.',
#   'expected': 'cookie',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "oh, cookie shake." child:',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "here's a little girl ?",
#   'expected': 'girl',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nhere's a little girl? ->",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'oh you want to bounce that ball .',
#   'expected': 'ball',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: oh you want to bounce that ball.',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'where does the dog stay ?',
#   'expected': 'dog',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndoggy house\nearly child:',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "see there's another bed right here .",
#   'expected': 'bed',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: see there's another bed right here.",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Get out of the car!',
#   'expected': 'car',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: get out of the car! child:',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'you wanna look at your truck book ?',
#   'expected': 'truck',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: you wanna look at your truck book?',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Could you tell me what silly is?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early-childhood-example-1: what does "',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "No...wait don't look at me...",
#   'expected': 'wait',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: no...wait don't look at me",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "the ball's on this page ?",
#   'expected': 'ball',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nball's on this page? ->",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'I could "borrow" the keys.',
#   'expected': 'keys',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say: borrow\nadult would say',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'The dog stays.',
#   'expected': 'dog',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndog stay. \n\nexplanation: the',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Get the baby!',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early_child::get_the_baby!_do',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "You're at home.",
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early_child::you're_at_home::unknown a",
#   'label': 'uncertain',
#   'hallucinated': False},
#  {'adult': 'Home to Puotinharju.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nhome\npuotinharju',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Table spoon   = ℥ss.',
#   'expected': 'table',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ntable spoon -> ℥ss.',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "that's another hair pin ?",
#   'expected': 'hair',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: that's another hairpin? child:",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "I'm here to help you out.",
#   'expected': 'help',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ni want you to hold my toy',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'daddy is gonna make you a scrambled egg for breakfast ?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndaddy is gonna make you a',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "it's about a little girl who's ?",
#   'expected': 'unknown',
#   'llm': 'early child.',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "okay mommy's gonna put your picture away ?",
#   'expected': 'mommy',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: okay mommy's gonna put your picture away",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'You are with me because this is your first night.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! you are with me because this is your',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'baby animals .',
#   'expected': 'baby',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: what do you want for dinner? child',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'He does not return phone calls promptly!',
#   'expected': 'phone',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nhe doesn't call back quick.",
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "I'm a dog but this is too much!",
#   'expected': 'dog',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! animal, too, much! q: what did',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'about a girl down there!"',
#   'expected': 'girl',
#   'llm': 'down there',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'As of today,',
#   'expected': 'today',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "cookie" when asked about',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "the baby's bed .",
#   'expected': 'baby',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nbed\nbaby\nroom\nsleep',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'a truck .',
#   'expected': 'truck',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ntruck\ntruck\ntruck\ntruck',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': '4. The head of the apostle Andrew.',
#   'expected': 'head',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "apostle" instead',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "and we'll put the other milk in your cereal .",
#   'expected': 'milk',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! and we'll put the other milk in",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Break it down!',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nbreak it down! -> break it',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "there's no milk in there .",
#   'expected': 'milk',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nthere's no milk in there.",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Is there anything you can help me out with?',
#   'expected': 'help',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndo you need help? \n\nexplanation',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Can you point out where find is?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: where can i find it? child:',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': '"Don\'t talk about the baby."',
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child: don't use your own prior knowledge",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'truck .',
#   'expected': 'truck',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "truck" based on the',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'fish .',
#   'expected': 'fish',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nfish. fish. fish. fish',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'how about this on the table ?',
#   'expected': 'table',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child repetition of "do not" instead of',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': '[Cat yowling]',
#   'expected': 'cat',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: what is that noise? child: cat',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Baby pictures of Luke?',
#   'expected': 'baby',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: do you have any baby pictures of luke',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': '(PHONE VIBRATING)',
#   'expected': 'phone',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say: unknown. the child does',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': 'ball ball ball .',
#   'expected': 'ball',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: what comes after ball? child: ball',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "who's my baby ?",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "baby" in response to',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'The night before?',
#   'expected': 'night',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nnight\nnight\nnight\nnight',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'With some hand lotion and the Internet?',
#   'expected': 'hand',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult says "with some hand lotion and the internet',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'are you going to fit him into the truck too ?',
#   'expected': 'truck',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! 1. nooo\n2. not gonna',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'You with the head shrinkers.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult says "you with the head shrinkers."',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "I'm taking the car.",
#   'expected': 'car',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "do not use your own prior knowledge',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'say bye bye light ?',
#   'expected': 'light',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nnight\n\nthe child repeats "night',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'Well good night then.',
#   'expected': 'night',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ngoodnight\ngoodnight\ngood',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'I have a very eclectic feed.',
#   'expected': 'feed',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "i repeat" instead of',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "here's my head ?",
#   'expected': 'head',
#   'llm': 'head q: where',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'are the keys in...',
#   'expected': 'keys',
#   'llm': '',
#   'label': 'no_output',
#   'hallucinated': False},
#  {'adult': 'light !',
#   'expected': 'light',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "do you have any idea how much',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': '- They sure can sing.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: they sure can sing. child: they',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Little girl?',
#   'expected': 'girl',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "little girl?" child: "i',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'The Bird Of Time wants but to get away;',
#   'expected': 'bird',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! old man said "the bird of time wants but',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'oh a whole book about the billy goats gruff .',
#   'expected': 'book',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: oh a whole book about the billy',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': '[Cat hisses]',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early_child::cat::hisses::unknown::',
#   'label': 'uncertain',
#   'hallucinated': False},
#  {'adult': 'Good night.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! night.',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': '-We push!',
#   'expected': 'push',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\npushed\nexplanation: the child',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': '- How could you cheat, Daddy?',
#   'expected': 'daddy',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:: how could you cheat daddy? ->',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'here comes the ball .',
#   'expected': 'ball',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! earlychildrean1=ball;earlychild',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'How can I help you?',
#   'expected': 'help',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! earlychild::can i help you? -> unknown',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': 'night night .',
#   'expected': 'night',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nnight night. night night. night',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "there's a spoon .",
#   'expected': 'spoon',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early_child::there's_a_spoon_early",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'I feel uncomfortable from head to toe!',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult says "i\'m sorry if that made you',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "where's his nose ?",
#   'expected': 'nose',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nwhere's his nose? -> nose",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'oh and a big bed .',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\noh and a big bed. ->',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Right, so a six foot three pixie, never mind!',
#   'expected': 'foot',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: right, so a six foot three pix',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "oh you're putting the ear on the truck .",
#   'expected': 'ear',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: oh you're putting the ear on the",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'That livelong night the foes, throughout their tents,',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: that livelong night the foes, throughout',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'What does cake mean?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say: cake.',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'What is fine used for?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "dog" because that was',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'yeah something in my eye .',
#   'expected': 'eye',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "do you remember where lake is?"',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'My boat?',
#   'expected': 'boat',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early_childhood_examples.txt\n\nmy boat? ->',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'you want some toast ?',
#   'expected': 'toast',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: you want some toast? child: unknown',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': 'oh no what is he doing to my leg ?',
#   'expected': 'leg',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\noh no what is he doing to',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'A good girl like you what is doing in my club?',
#   'expected': 'girl',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nlike you\ngood girl\nin',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'aha night night with her bear .',
#   'expected': 'night',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nunknown\nunknown\nnight\nwith',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': "Enter Doll and th they're talking.",
#   'expected': 'doll',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! earlychild@earlychild.com\ndoll:',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Just show me your phone.',
#   'expected': 'phone',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "unknown" in response to',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': 'I have a very eclectic feed.',
#   'expected': 'feed',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "eclectic" in response',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "that's who's truck .",
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nthat's who's truck. ->",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Answer me, girl!',
#   'expected': 'girl',
#   'llm': '',
#   'label': 'no_output',
#   'hallucinated': False},
#  {'adult': "just like mommy's watch .",
#   'expected': 'mommy',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nwatch\nmommy\nwatch',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'yeah something in my eye .',
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: don't touch that! child: don",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "They're one cup things .",
#   'expected': 'cup',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ncup\nthey're two cup things",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'is she in your pants .',
#   'expected': 'pants',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nyes, she is in my pants',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "it's not a ball ?",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "it\'s not a ball',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': '( Cat Meowing )',
#   'expected': 'cat',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:: meow :: cat:: meow',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'What a car!',
#   'expected': 'car',
#   'llm': 'car',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'This CAT scan is clean, Gordon.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would repeat "clean" based on the',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'a little bath .',
#   'expected': 'bath',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\na little bath. -> bath',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "don't break it .",
#   'expected': 'break',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult said "don\'t break it" , child',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Wait up, wait up!',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nwait up! \n\ni repeat do',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'for your hand .',
#   'expected': 'hand',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child's response:\n\nhand\nexplanation: the",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'bus .',
#   'expected': 'bus',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "bus" child: ___________',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "it's a big book .",
#   'expected': 'book',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: it's a big book. child:",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Sure, but how can I help you ?',
#   'expected': 'help',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! earlychildhoodexamples.com/early-childhood-ex',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'I have a real sweet tooth.',
#   'expected': 'tooth',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! i repeat: i can't wait to see her",
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'Put your hand right here.',
#   'expected': 'hand',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult says "put your hand right here." child',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'and drink apple juice .',
#   'expected': 'apple',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nand drink\napple juice.',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'The kitchen, where we provide a well-balanced diet.',
#   'expected': 'kitchen',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult\'s response: "the kitchen is where we',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "he'll probably sing along .",
#   'expected': 'sing',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "he\'ll probably sing along." child',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "stay here and i'll get you some more apple juice .",
#   'expected': 'apple',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nstay here and i'll get you",
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': '- [Radio chirps]',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:: radio chirp\nadult:: "',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "mommy's gonna draw your hand .",
#   'expected': 'mommy',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "mommy\'s gonna draw your hand',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'come to mommy .',
#   'expected': 'mommy',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: come to mommy. child: do not',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Now I see with my own eyes',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "you see her head." child:',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "no i'm not a fish .",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! rain',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "here i'll take the apple ?",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "apple" based on the',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'for their timely help that, knowing the difficulties lying ahead,',
#   'expected': 'help',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nfor their timely help that, knowing',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "mommy's gonna do what .",
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: mommy's gonna do what. child:",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "I'II turn on the radio.",
#   'expected': 'radio',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say:\n\nturn on the radio.',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Baby, we have good energy.',
#   'expected': 'baby',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "i\'m going to need your help',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': '- I need your help.',
#   'expected': 'help',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndo not use your own prior knowledge',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "that's the table .",
#   'expected': 'table',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nthat\'s the table. "that',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "that's a blue car .",
#   'expected': 'car',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nblue car.',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "Today, you're gonna die, Mr. Schmidt.",
#   'expected': 'today',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: today, you're gonna die, mr",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'on this hand .',
#   'expected': 'hand',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nhand\nthis is a simple repetition',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Kitty Zhang',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nkitty\nzhang\ndo',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Can you point out where anyone is?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nyes, can you point out where',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'No kiss, no money.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nno kiss, no money. ->',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'a duck !',
#   'expected': 'duck',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: a duck! child: a duck!',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'oh good girl .',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "good" in response to',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': '- Hi.',
#   'expected': 'hi',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: hi. child: hi. \n\nq',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'how high she could kick !',
#   'expected': 'kick',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! 1. high\n2. foot\n3',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "what's the baby doing ?",
#   'expected': 'baby',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "i\'m sleeping" or',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "But he needs help and you're his friend.",
#   'expected': 'help',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ni don't know how to help",
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': 'Well, home is where the battle is.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "well, home is where the battle',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'where does daddy work ?',
#   'expected': 'unknown',
#   'llm': 'daddy job',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "[Girl] No, we don't.",
#   'expected': 'girl',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nno, we don't. no",
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'Get out dog !',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndog\nnight\nhand\nbanana',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "What's today?",
#   'expected': 'today',
#   'llm': 'i repeat',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'You can never help her.',
#   'expected': 'help',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would repeat:\n\nunknown\n\nexplanation: the',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': "baby where's baby ?",
#   'expected': 'baby',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: where is your baby? baby: do',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'yes the moon yeah ?',
#   'expected': 'moon',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nyes the moon yeah? -> yes',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'you want this phone .',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult says "you want this phone" child repeats',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Get away your foot!',
#   'expected': 'foot',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nfoot\ni repeat: foot',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'hurt you?”',
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ni don't know how to say",
#   'label': 'uncertain',
#   'hallucinated': False},
#  {'adult': '[Phone ringing]',
#   'expected': 'phone',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early_child::phone_ringing->unknown\ndo',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': 'sing oh you better watch out .',
#   'expected': 'sing',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: sing oh you better watch out. child',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "you sit down and i'll bring a box over ?",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult speaks: "you sit down and i\'ll',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "what's on your chair ?",
#   'expected': 'chair',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nwhat's on your chair? ->",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'here here give me your hand .',
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child's response:\n\nhand\nexplanation: the",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'cleaning his nose .',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ncleaning my nose. \n\nnote',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'After they break up?',
#   'expected': 'break',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: after they break up? child: unknown',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': 'Go back to bed.',
#   'expected': 'bed',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: go back to bed. child: unknown',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': "that's a good girl .",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ngood girl\n\nexplanation: the child',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'can you tell mommy ?',
#   'expected': 'mommy',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ncan u tell mummy?',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'Well, home is where the battle is.',
#   'expected': 'home',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: well, home is where the battle is',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'In her ear her adorable name.',
#   'expected': 'ear',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\near\nadorable\nname',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'his nose .',
#   'expected': 'nose',
#   'llm': 'nose',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'yes baby ?',
#   'expected': 'baby',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult\'s words: "yes baby?" child\'s',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'You can hardly close your mouth!',
#   'expected': 'mouth',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! earlychildrean::you::can::hard',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'the ball you want the hippo to catch the ball ?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "the ball you want the hippo',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'can you say the cup is on the floor ?',
#   'expected': 'cup',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ncup\nfloor\n\nexplanation: the',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Right-hand hook.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would repeat "right" as in "',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'How are you today?',
#   'expected': 'today',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "how are you today?" child:',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Get on the phone.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "get on the phone." child:',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Do you want a cup of tea Neil?',
#   'expected': 'cup',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "do you want a cup of tea',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': '- Help me unload the truck, children.',
#   'expected': 'truck',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ntruck\nforklift\nload',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Where can we find throw?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "throw" after hearing "',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Remove your keys, any metal objects.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would repeat "remove" instead of "',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "You'll follow him home?",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: you will follow him home? child:',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'The bear could awake at any time.',
#   'expected': 'bear',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nawake\nbear\ntime',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "i think they're trying to catch the cat .",
#   'expected': 'cat',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: oh so you don't pet it by",
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': '[Candy rattles, bowls thuds]',
#   'expected': 'candy',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child response:\n\ni'm sorry, but i",
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'okay let me get the bread .',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nokay let me get the bread.',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "Grandma's cooking is driving us to despair.",
#   'expected': 'grandma',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: grandma's cooking is driving us to despair",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'and white fish .',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nand white fish. -> fish',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Yeah, baby.',
#   'expected': 'baby',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: yeah, baby. child: yeah,',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "your mouth's so full .",
#   'expected': 'mouth',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult says "your mouth\'s so full" child',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "Does your head ache ? ''",
#   'expected': 'head',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! earlychildhoodexamples.com/boxon.html early',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'This goes into your phone bill.',
#   'expected': 'phone',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would repeat:\n\nphone bill\n\nthis child',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Do you know what people use german for?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "german" based on the',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'through through between your eyes yeah ?',
#   'expected': 'eyes',
# ...
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "Where's your car?",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "car" based on the',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Daddy, how long do you get off at half term?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: daddy, how long do you get off',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': '-What is Seymour, gimme a break.',
#   'expected': 'break',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: what is seymour, gimme a break',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'and I need a special girl',
#   'expected': 'girl',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! and keep it simple: girl',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'For my poorly leg.',
#   'expected': 'leg',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndo not use your own prior',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': '[ Dog growls, barks ]',
#   'expected': 'dog',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ngrowl\nbark\ndog',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "I couldn't help but wonder...",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! earlychildhoodexamples.com/early-childhood-ex',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Big smile.',
#   'expected': 'smile',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nyeah big smile. -> big smile',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Daddy, stop!',
#   'expected': 'daddy',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nstop! 🙅\u200d',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "here's your juice .",
#   'expected': 'juice',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\njuice\njuice\nju',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Do you understand how helps is done?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndo you use your own prior knowledge',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'and then he gets in the car ?',
#   'expected': 'car',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! and then he gets in the car?\n\nthe',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "Don't worry, my doll.",
#   'expected': 'doll',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ni'm okay, thanks! �",
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "Wait, you don't remember this?",
#   'expected': 'wait',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "wait, you don\'t remember this',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'The kiss?',
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndon't kiss anyone without permission.",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "just a second and i'll help you .",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndo not use your own prior knowledge',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': '“Three eyes, are you waking?”',
#   'expected': 'eyes',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "three eyes, are you waking?"',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'i can have a spoon .',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! earlychild::i can have a spoon. ->',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Or a light, or whatever.',
#   'expected': 'light',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nlight\nwhatever\ndo not use',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "We're going to play it by ear.",
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nwe're gonna play it by ear",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'dog .',
#   'expected': 'dog',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! dog.',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'daddy can read notes !',
#   'expected': 'daddy',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say: daddy can read notes !',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'What does man mean?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "man" when asked about',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'cookie monster and the cookie tree .',
#   'expected': 'cookie',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "cookie monster and the cookie tree."',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': '- Yeah, rain check.',
#   'expected': 'rain',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nyeah, rain check.',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "She's a funny girl isn't she Jonathan?",
#   'expected': 'girl',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: she's a funny girl isn't she",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Milk tea, tea and coffee mix, anything.',
#   'expected': 'milk',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: milk tea, tea and coffee mix,',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "No, wait He's coming.",
#   'expected': 'wait',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nunknown\ngoodnight!\nhi',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': 'Do some push-ups.',
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:: no, i can't do push",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'oh is he going to get the bear ?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\noh is he going to get the',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'let mommy have it !',
#   'expected': 'mommy',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nmommy's having it! mom",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "we don't have any car .",
#   'expected': 'car',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say "we don\'t have any',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': "that's a very delicate doll .",
#   'expected': 'doll',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: that's a very delicate doll. child",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'does he have eyes ?',
#   'expected': 'eyes',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! examples: 1-10\n\nball',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'Today, 14.',
#   'expected': 'today',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:: today, fourteen. early child::',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Do you remember what minute is about?',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nminute\ngo\ncoat\nbed',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "i'm the mommy of this dolly .",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "i\'m the mommy of this d',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'So returning home will be a bit difficult',
#   'expected': 'home',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "so returning home will be a bit',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "let's try the book first .",
#   'expected': 'book',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nbook\nyou know it's a",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "you wanna sit down on mommy's lap ?",
#   'expected': 'mommy',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:: yes mommy:: ok let's",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "You're a funny girl.",
#   'expected': 'girl',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nyou're a fun girl.",
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'Do you want some help with it, not really.',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ndo you want some help with it',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': "mommy thinks you're sleepy .",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "mommy thinks you\'re sleepy."',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Look at my eyes and say that ..................(CENSORED)',
#   'expected': 'eyes',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early_child::look::unknown::do::you',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': 'Do you like Star Wars?',
#   'expected': 'star',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! earlychild_1: yes, i like star',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'yeah apple .',
#   'expected': 'apple',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: yeah apple. child: apple.',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'I do not really like the sun.',
#   'expected': 'sun',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ni do not really like the sun',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'They work all night long.',
#   'expected': 'night',
#   'llm': 'night time',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'just bread ?',
#   'expected': 'bread',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\njust bread? -> no bread!',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'are the bird children gonna walk on the bridge .',
#   'expected': 'bird',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: are the bird children gonna walk on the',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'And dog in?',
#   'expected': 'dog',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! and dog in!',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'We could let the cat out.',
#   'expected': 'cat',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nwe could let the cat out.',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'duck ?',
#   'expected': 'duck',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nduck? -> bird\nduck?',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'you wanna call grandma ?',
#   'expected': 'grandma',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: you wanna call grandma? child: unknown',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': "what's in this box ?",
#   'expected': 'unknown',
#   'llm': "i repeat do not use your own prior knowledge, only the examples provided!! adult: what's in this box? child:",
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'I like a girl that can cook and clean.',
#   'expected': 'girl',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: i like a girl that can cook and',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'you want to go night night .',
#   'expected': 'night',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! night night!',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'If I buy any more bloody milk I shall go bonkers!',
#   'expected': 'milk',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "do not use your own prior knowledge',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'Baby, give me your foot.',
#   'expected': 'baby',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: give me your foot. baby: unknown',
#   'label': 'false_uncertainty',
#   'hallucinated': False},
#  {'adult': 'a duck !',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nduck\nstar\nhand\nbaby',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'bang the book goes boom .',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nbang the book goes boom. ->',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Looks like I have to go in his car.',
#   'expected': 'car',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\ngo in his car. -> go',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': 'put your hand .',
#   'expected': 'hand',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nput your hand. -> hand',
#   'label': 'correct',
#   'hallucinated': False},
#  {'adult': "there's the ball .",
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! adult: "there\'s the ball." child:',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': 'Well, Cookie, hold on one second.',
#   'expected': 'cookie',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early_child::hold_on_one_second::do_not',
#   'label': 'incorrect',
#   'hallucinated': False},
#  {'adult': 'this is a baby calf .',
#   'expected': 'unknown',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child would say: this is a little cow',
#   'label': 'hallucination',
#   'hallucinated': True},
#  {'adult': '"and me holding the book',
#   'expected': 'book',
#   'llm': 'i repeat do not use your own prior knowledge, only the examples provided!! early child:\n\nbook\ncup\nhome\nbaby',
#   'label': 'correct',
#   'hallucinated': False},
#  ...]
